# %%
import pandas as pd

# %%
suicides = pd.read_csv("../data/master_oecd.csv")
alcohol = pd.read_csv("../data/alcohol_per_capita2.csv")
poverty = pd.read_csv("../data/poverty.csv")
working_hours = pd.read_csv("../data/work_df.csv")
economic = pd.read_csv("../data/economic_info.csv")

# %%
suicides.head()
# Out:
#   continent    country  year          age  suicides_no  population  \
# 0   Oceania  AUSTRALIA  1985  15-24 years          384     2659800
# 1   Oceania  AUSTRALIA  1985  25-34 years          421     2575000
# 2   Oceania  AUSTRALIA  1985  35-54 years          554     3739500
# 3   Oceania  AUSTRALIA  1985   5-14 years            8     2522000
# 4   Oceania  AUSTRALIA  1985  55-74 years          391     2464300
#
#    gdp_per_capita ($)  s_rate  oecd
# 0               12374   14.44     1
# 1               12374   16.35     1
# 2               12374   14.81     1
# 3               12374    0.32     1
# 4               12374   15.87     1

# %%
alcohol.head()
# Out:
#    year  alcohol per capita            country
# 0  1961                0.41  REPUBLIC OF KOREA
# 1  1962                0.41  REPUBLIC OF KOREA
# 2  1963                0.34  REPUBLIC OF KOREA
# 3  1964                0.33  REPUBLIC OF KOREA
# 4  1965                0.50  REPUBLIC OF KOREA

# %%
df1 = suicides.merge(alcohol, how="left", on=["country","year"])

# %%
poverty.head()
# Out:
#      country  year  pov_rate
# 0  AUSTRALIA  2012     0.140
# 1  AUSTRALIA  2014     0.128
# 2  AUSTRALIA  2016     0.121
# 3  AUSTRALIA  2018     0.124
# 4    AUSTRIA  2007     0.097

# %%
df2 = df1.merge(poverty, how="left", on=["country","year"])

# %%
df2.head()
# Out:
#   continent    country  year          age  suicides_no  population  \
# 0   Oceania  AUSTRALIA  1985  15-24 years          384     2659800
# 1   Oceania  AUSTRALIA  1985  25-34 years          421     2575000
# 2   Oceania  AUSTRALIA  1985  35-54 years          554     3739500
# 3   Oceania  AUSTRALIA  1985   5-14 years            8     2522000
# 4   Oceania  AUSTRALIA  1985  55-74 years          391     2464300
#
#    gdp_per_capita ($)  s_rate  oecd  alcohol per capita  pov_rate
# 0               12374   14.44     1                 NaN       NaN
# 1               12374   16.35     1                 NaN       NaN
# 2               12374   14.81     1                 NaN       NaN
# 3               12374    0.32     1                 NaN       NaN
# 4               12374   15.87     1                 NaN       NaN

# %%
economic.head()
# Out:
#      country  year  household debt  labour comp per hour age group  \
# 0  Australia  1995        94.86145              5.638905       NaN
# 1  Australia  1996        98.62147              6.317506       NaN
# 2  Australia  1997       106.62240              2.936676       NaN
# 3  Australia  1998       114.09520              3.603118       NaN
# 4  Australia  1999       120.42900              1.888844       NaN
#
#    poverty rate  internet access  unemployment rate
# 0           NaN              NaN           8.472281
# 1           NaN              NaN           8.506114
# 2           NaN              NaN           8.362488
# 3           NaN              NaN           7.677429
# 4           NaN              NaN           6.873791

# %%
eco = economic.drop(columns=["age group","poverty rate","internet access"])

# %%
eco["country"]=eco["country"].str.upper()

# %%
df3 = df2.merge(eco, how="left", on=["country","year"])

# %%
df3.head()
# Out:
#   continent    country  year          age  suicides_no  population  \
# 0   Oceania  AUSTRALIA  1985  15-24 years          384     2659800
# 1   Oceania  AUSTRALIA  1985  25-34 years          421     2575000
# 2   Oceania  AUSTRALIA  1985  35-54 years          554     3739500
# 3   Oceania  AUSTRALIA  1985   5-14 years            8     2522000
# 4   Oceania  AUSTRALIA  1985  55-74 years          391     2464300
#
#    gdp_per_capita ($)  s_rate  oecd  alcohol per capita  pov_rate  \
# 0               12374   14.44     1                 NaN       NaN
# 1               12374   16.35     1                 NaN       NaN
# 2               12374   14.81     1                 NaN       NaN
# 3               12374    0.32     1                 NaN       NaN
# 4               12374   15.87     1                 NaN       NaN
#
#    household debt  labour comp per hour  unemployment rate
# 0             NaN                   NaN                NaN
# 1             NaN                   NaN                NaN
# 2             NaN                   NaN                NaN
# 3             NaN                   NaN                NaN
# 4             NaN                   NaN                NaN

# %%
working_hours.head()
# Out:
#              country  year  work_hours
# 0  REPUBLIC OF KOREA  2000        2512
# 1  REPUBLIC OF KOREA  2001        2499
# 2  REPUBLIC OF KOREA  2002        2464
# 3  REPUBLIC OF KOREA  2003        2424
# 4  REPUBLIC OF KOREA  2004        2392

# %%
working_hours["country"]=working_hours["country"].str.upper()

# %%
df4 = df3.merge(working_hours, how="left", on=["country","year"])

# %%
df4[df4["year"]==2015]
# Out:
#         continent        country  year          age  suicides_no  population  \
# 210       Oceania      AUSTRALIA  2015  15-24 years          391     3135295
# 211       Oceania      AUSTRALIA  2015  25-34 years          542     3509980
# 212       Oceania      AUSTRALIA  2015  35-54 years         1238     6352942
# 213       Oceania      AUSTRALIA  2015   5-14 years           14     2935661
# 214       Oceania      AUSTRALIA  2015  55-74 years          609     4748773
# ...           ...            ...   ...          ...          ...         ...
# 11166  N. america  UNITED STATES  2015  55-74 years        11940    67380307
# 11167  N. america  UNITED STATES  2015    75+ years         3711    19949802
# 11168  N. america  UNITED STATES  2015    75+ years         3711    19949802
# 11169  N. america  UNITED STATES  2015    75+ years         3711    19949802
# 11170  N. america  UNITED STATES  2015    75+ years         3711    19949802
#
#        gdp_per_capita ($)  s_rate  oecd  alcohol per capita  pov_rate  \
# 210                 60656   12.47     1                 NaN       NaN
# 211                 60656   15.44     1                 NaN       NaN
# 212                 60656   19.49     1                 NaN       NaN
# 213                 60656    0.48     1                 NaN       NaN
# 214                 60656   12.82     1                 NaN       NaN
# ...                   ...     ...   ...                 ...       ...
# 11166               60387   17.72     1                3.07     0.168
# 11167               60387   18.60     1                3.07     0.168
# 11168               60387   18.60     1                3.07     0.168
# 11169               60387   18.60     1                3.07     0.168
# 11170               60387   18.60     1                3.07     0.168
#
#        household debt  labour comp per hour  unemployment rate  work_hours
# 210          199.3722              2.681951           6.056423      1682.0
# 211          199.3722              2.681951           6.056423      1682.0
# 212          199.3722              2.681951           6.056423      1682.0
# 213          199.3722              2.681951           6.056423      1682.0
# 214          199.3722              2.681951           6.056423      1682.0
# ...               ...                   ...                ...         ...
# 11166        109.0323              2.743944           5.291667      1786.0
# 11167        109.0323              2.743944           5.291667      1786.0
# 11168        109.0323              2.743944           5.291667      1786.0
# 11169        109.0323              2.743944           5.291667      1786.0
# 11170        109.0323              2.743944           5.291667      1786.0
#
# [642 rows x 15 columns]

# %%
pension = pd.read_csv("../data/pension_df.csv")
inequality= pd.read_csv("../data/inequality_df.csv")

# %%
pension.head()
# Out:
#      country  year  %gdp_pen
# 0  AUSTRALIA  2015     4.327
# 1  AUSTRALIA  2016     4.176
# 2    AUSTRIA  2015    13.304
# 3    BELGIUM  2015    10.709
# 4     CANADA  2015     4.698

# %%
inequality
# Out:
#       country  year  inqlt_rate
# 0   AUSTRALIA  2016       0.330
# 1   AUSTRALIA  2018       0.325
# 2     AUSTRIA  2015       0.275
# 3     AUSTRIA  2016       0.284
# 4     AUSTRIA  2017       0.275
# ..        ...   ...         ...
# 86     LATVIA  2016       0.346
# 87     LATVIA  2017       0.355
# 88  LITHUANIA  2015       0.372
# 89  LITHUANIA  2016       0.378
# 90  LITHUANIA  2017       0.374
#
# [91 rows x 3 columns]

# %%
df5 = df4.merge(pension, how="left", on=["country","year"])

# %%
df6 = df5.merge(inequality, how="left", on=["country","year"])

# %%
df6.loc[df6["country"] == "REPUBLIC OF KOREA"]
# Out:
#      continent            country  year          age  suicides_no  population  \
# 8529      Asia  REPUBLIC OF KOREA  1985  15-24 years          974     8561300
# 8530      Asia  REPUBLIC OF KOREA  1985  25-34 years          883     7185600
# 8531      Asia  REPUBLIC OF KOREA  1985  35-54 years         1165     8553100
# 8532      Asia  REPUBLIC OF KOREA  1985   5-14 years           33     8392400
# 8533      Asia  REPUBLIC OF KOREA  1985  55-74 years          554     3498800
# ...        ...                ...   ...          ...          ...         ...
# 8728      Asia  REPUBLIC OF KOREA  2015  55-74 years         4113    10484510
# 8729      Asia  REPUBLIC OF KOREA  2015    75+ years         2079     2665702
# 8730      Asia  REPUBLIC OF KOREA  2015    75+ years         2079     2665702
# 8731      Asia  REPUBLIC OF KOREA  2015    75+ years         2079     2665702
# 8732      Asia  REPUBLIC OF KOREA  2015    75+ years         2079     2665702
#
#       gdp_per_capita ($)  s_rate  oecd  alcohol per capita  pov_rate  \
# 8529                2731   11.38     1                0.44       NaN
# 8530                2731   12.29     1                0.44       NaN
# 8531                2731   13.62     1                0.44       NaN
# 8532                2731    0.39     1                0.44       NaN
# 8533                2731   15.83     1                0.44       NaN
# ...                  ...     ...   ...                 ...       ...
# 8728               28410   39.23     1                0.64     0.175
# 8729               28410   77.99     1                0.64     0.175
# 8730               28410   77.99     1                0.64     0.175
# 8731               28410   77.99     1                0.64     0.175
# 8732               28410   77.99     1                0.64     0.175
#
#       household debt  labour comp per hour  unemployment rate  work_hours  \
# 8529             NaN                   NaN                NaN         NaN
# 8530             NaN                   NaN                NaN         NaN
# 8531             NaN                   NaN                NaN         NaN
# 8532             NaN                   NaN                NaN         NaN
# 8533             NaN                   NaN                NaN         NaN
# ...              ...                   ...                ...         ...
# 8728        162.2843             -4.106868           3.591667      2082.0
# 8729        162.2843             -4.106868           3.591667      2082.0
# 8730        162.2843             -4.106868           3.591667      2082.0
# 8731        162.2843             -4.106868           3.591667      2082.0
# 8732        162.2843             -4.106868           3.591667      2082.0
#
#       %gdp_pen  inqlt_rate
# 8529       NaN         NaN
# 8530       NaN         NaN
# 8531       NaN         NaN
# 8532       NaN         NaN
# 8533       NaN         NaN
# ...        ...         ...
# 8728       NaN         NaN
# 8729       NaN         NaN
# 8730       NaN         NaN
# 8731       NaN         NaN
# 8732       NaN         NaN
#
# [204 rows x 17 columns]

# %%
df6.to_csv("../data/final_df.csv", index=False)
