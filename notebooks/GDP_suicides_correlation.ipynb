# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv("../data/master_grouped_ccy.csv")
df = df.drop(columns="Unnamed: 0")
df.head()
# Out:
#   continent  country  year  suicides_no  population  gdp_per_capita ($)  \
# 0    Europe  Albania  1987           73     2709600                 796
# 1    Europe  Albania  1988           63     2764300                 769
# 2    Europe  Albania  1989           68     2803100                 833
# 3    Europe  Albania  1992           47     2822500                 251
# 4    Europe  Albania  1993           73     2807300                 437
#
#    s_rate
# 0    2.69
# 1    2.28
# 2    2.43
# 3    1.67
# 4    2.60

# %%
df_cor = sm.add_constant(df)

# %%
y = df_cor["suicides_no"]
X = df_cor[["const", "gdp_per_capita ($)"]]

lin_reg = sm.OLS(y,X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            suicides_no   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     19.12
# Date:                Tue, 28 Apr 2020   Prob (F-statistic):           1.28e-05
# Time:                        15:21:36   Log-Likelihood:                -23612.
# No. Observations:                2296   AIC:                         4.723e+04
# Df Residuals:                    2294   BIC:                         4.724e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               2359.1973    198.572     11.881      0.000    1969.798    2748.596
# gdp_per_capita ($)     0.0341      0.008      4.373      0.000       0.019       0.049
# ==============================================================================
# Omnibus:                     2142.600   Durbin-Watson:                   0.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            65422.675
# Skew:                           4.582   Prob(JB):                         0.00
# Kurtosis:                      27.493   Cond. No.                     3.42e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.42e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
